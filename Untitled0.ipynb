# %% [markdown]
# <a href="https://colab.research.google.com/github/juanchamorro21/POO/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Entorno y Flujo de TrabajoEcosistema Tecnológico: Las herramientas base recomendadas son Python Data Stack, Scikit-learn, Google Colab (en la nube) y Git / GitHub Enterprise para el control de versiones.Fuga de Datos (Data Leakage): Es un error crítico que ocurre cuando la información del conjunto de prueba se filtra al de entrenamiento, lo que invalida y falsea la precisión real del modelo.Pipeline de Datos: El proceso estándar sigue cuatro pasos secuenciales:Imputación: Tratamiento y relleno de datos nulos.Escalamiento: Normalización de escalas numéricas.Reducción: Compresión dimensional de las variables.Clasificador: Estimador final y predicción algorítmica.2. Algoritmos y Técnicas AvanzadasBagging vs. Boosting (Modelos de Ensamble):Bagging: Reduce la varianza usando árboles aleatorios trabajando en paralelo (ej. Random Forest).Boosting: Reduce el sesgo corrigiendo errores de forma iterativa y secuencial (ej. XGBoost).Truco del Kernel (Kernel Trick): Es una función que proyecta datos a dimensiones superiores para poder resolver y separar problemas no lineales en algoritmos SVM (Support Vector Machines).3. Algoritmos No SupervisadosAlgoritmoFunciónAplicaciónK-MeansAgrupamiento (Clustering)Segmentación de mercado o clientes.DBSCANDensidadEstudios demográficos basados en densidad espacial.Isolation ForestAnomalíasDetección de fraude o comportamientos inusuales.4. Optimización de HiperparámetrosGridSearchCV: Realiza búsquedas exhaustivas combinando todos los parámetros posibles. Encuentra la mejor opción, pero es un proceso muy lento y costoso a nivel computacional.RandomizedSearchCV: Realiza exploraciones aleatorias y automatizadas. Es un enfoque mucho más ágil, rápido y eficiente para optimizar el modelo.
