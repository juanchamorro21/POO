# %% [markdown]
# <a href="https://colab.research.google.com/github/juanchamorro21/POO/blob/main/sesion14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 01 Maldición Dimensionalidad: Concepto fundamental sobre los desafíos que surgen al trabajar con datos de alta dimensionalidad. 02 Proyección y Variedades: Estudio de cómo proyectar los datos y entender las variedades (manifolds) subyacentes. 03 Tutorial Técnico: PCA: Explicación práctica y técnica sobre el Análisis de Componentes Principales (PCA). 04 Optimizando PCA: Métodos y enfoques para mejorar o ajustar el rendimiento de PCA. 05 LLE y Otras Técnicas: Introducción a técnicas alternativas de reducción de dimensionalidad como LLE (Locally Linear Embedding)
